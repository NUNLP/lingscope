# %%
import xml.etree.ElementTree as ET

# %%
root = ET.parse("../../../data/full_papers.xml")
tree = root.getroot()

# %%
for element in tree.iter():
    #print element.text
    for doc in element.findall("DocID"):
        print doc.text
    #for sents in element.findall("sentence"):
        #print sents.text
    for cue in element.findall("cue"):
        #print cue.attrib
        print cue.text
# Out:
# 1471-2105-8-225
# whether
# no
# unclear
# may
# Assuming
# no
# suggests
# or
# not
# not
# not
# suggests
# can
# raises an interesting question
# no
# would
# without
# would
# fail
# either
# or
# unlikely
# not
# could
# or
# may
# happens
# look like
# not
# not
# not
# not
# no
# not
# whether
# Instead of
# Whether
# or
# not
# not
# unlikely
# failed
# not
# apparent
# lack
# indicates that
# or
# not
# failed
# failed
# unclear
# whether
# absent
# not
# not
# no
# possible
# putative
# either
# or
# probably
# expect
# may
# not
# suggests
# lacks
# failed
# possibility
# no
# probably
# not
# no
# could
# no
# no guarantee
# whether
# neither
# nor
# not
# seems
# unlikely
# cannot
# considered
# no
# no
# not
# not
# cannot
# probably
# seems
# assume
# not
# not
# lack
# not
# may
# not
# likely
# or
# not
# may
# may
# possibility
# not
# may
# feasible
# may
# assumption
# without
# lack
# not
# assumes
# unclear
# whether
# not
# not
# may
# no
# may
# not
# not
# ...
